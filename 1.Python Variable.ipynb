# %% [markdown]
# ## **This is my first variable**

# %%
# my first var
var1= 45

# %%
#print
print(var1)
# Out:
# 45

# %%
var1
# Out:
# 45

# %%
# creating string var
name = 'Abhishek'

# %%
print(name)
# Out:
# Abhishek

# %%
name
# print function hide the data type
# Out:
# 'Abhishek'

# %%
# float var
var2 = 567.890

# %%
# type() : used to display the data type of given variable

# %%
type(var1)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
type(var2)
# Out:
# float

# %%
age = 1
Age=2
aGe=3
AGE=4
a_g_e = 5
_age= 6
age_ = 7
_AGE_ = 8

# %%
aGe
# Out:
# 3

# %%
# program to calculate area  of square
side = 7
area= side * side 
print(area)
# Out:
# 49

# %%
side = 7
area= side * side 
print('The area of Square ',area)
# Out:
# The area of Square  49

# %%
side = 7
area= side * side 
print('The area of Square '+ area)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-e5241d34e1de> in <cell line: 3>()
#       1 side = 7
#       2 area= side * side
# ----> 3 print('The area of Square '+ area)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# int() : 
# str()

# %%
side = 7
area= side * side 
print('The area of Square '+ str(area))
# Out:
# The area of Square 49

# %%
# to take input from user we input()
first_name = input('Enter your first name :')
second_name = input('Enter your last name :')
print(first_name ,second_name)
# Out:
# Enter your first name :Abhis
# Enter your last name :sri
# Abhis              sri

# %%
# integer input from input ()
# WAP to calculate area of rectangle
l = input('Enter the Length : ')
w = input('Enter the width : ')

area = l * w

print('area = ', area)
# Out:
# Enter the Length : 6
# Enter the width : 7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-c517a605cdc3> in <cell line: 6>()
#       4 w = input('Enter the width : ')
#       5
# ----> 6 area = l * w
#       7
#       8 print('area = ', area)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
type(l)
# Out:
# str

# %%
# WAP to calculate area of rectangle ( convert datatype)
l = int(input('Enter the Length : '))
w = int(input('Enter the width : '))
area = l * w
print('area = ', area)
# Out:
# Enter the Length : 5
# Enter the width : 6
# area =  30

# %%
# we can declare the multiple variable and assigning the value
x = 7
x = 6
x = 8
x = 10 
print(x)
# Out:
# 10

# %%
# we have different variable , we need to assign the same value
x = y= z = 78

# %%
x
# Out:
# 78

# %%
y
# Out:
# 78

# %%
z
# Out:
# 78

# %%
# we have different variable , we need to assign the different value

a,b,c = 7,8,9

# %%
b
# Out:
# 8
